# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/CensusFamilyIncome.csv'
data = pd.read_csv(file_path)

# Rename columns for easier access
data.columns = ['Year', 'Province', 'FamilySize', 'FamilyAgeGroup', 'NumEarners', 'IncomeGroup', 'ScalarFactor', 'Value']

# Grouping the data by Province to analyze key metrics
province_income = data.groupby('Province')['Value'].mean().reset_index()
province_family_size = data.groupby('Province')['FamilySize'].value_counts().unstack().fillna(0)
province_num_earners = data.groupby('Province')['NumEarners'].value_counts().unstack().fillna(0)

# EDA: Income distribution by province
plt.figure(figsize=(7,4))
sns.barplot(data=province_income, x='Province', y='Value')
plt.title('Average Family Income by Province')
plt.xticks(rotation=90)
plt.show()

# Grouping the data by Province for Family Size and Number of Earners
province_family_size = data_filtered.groupby('Province')['FamilySize'].value_counts().unstack().fillna(0)
province_num_earners = data_filtered.groupby('Province')['NumEarners'].value_counts().unstack().fillna(0)

# EDA: Family size distribution by province (bar plot)
plt.figure(figsize=(10,4))
sns.barplot(data=data_filtered, x='Province', y='Value', hue='FamilySize')
plt.title('Family Size Distribution by Province')
plt.xticks(rotation=90)
plt.show()

# EDA: Number of earners distribution by province (bar plot)
plt.figure(figsize=(6,4))
sns.barplot(data=data_filtered, x='Province', y='Value', hue='NumEarners')
plt.title('Number of Earners Distribution by Province')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
